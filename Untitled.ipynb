# %%
# basepath = 'C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL\\E2E_CNN_shoes_classification'

# %%
import os

# %%
file = 'image (4).jpg'

# %%
from werkzeug.utils import secure_filename
file_name = secure_filename(img)

# %%
file_path = os.path.join(
            basepath, 'uploads',file_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dae1796c5e9a> in <module>
#       1 file_path = os.path.join(
# ----> 2             basepath, 'uploads',file_name)
#
# NameError: name 'basepath' is not defined

# %%
file_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6249cc0b42e5> in <module>
# ----> 1 file_path
#
# NameError: name 'file_path' is not defined

# %%
pwd = 'C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL\\E2E_CNN_shoes_classification'

# %%
os.path.dirname(os.path.abspath(pwd))
# Out:
# 'C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL'

# %%
os.path.dirname(os.getcwd())
# Out:
# 'C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL'

# %%
for i in list(1,2,3):
    print(os.path.dirname())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-c3cac19bb626> in <module>
# ----> 1 for i in list(1,2,3):
#       2     print(os.path.dirname(i=i))
#       3
#
# TypeError: list expected at most 1 arguments, got 3

# %%
# Save the file to ./uploads
basepath =os.path.dirname(os.path.abspath("__file__"))
# basepath = 'C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL\\E2E_CNN_shoes_classification\\uploads'
file_path = os.path.join(basepath,'static\\uploads\\')

# %%
import matplotlib.pyplot as plt

# %%
arr = plt.imread(file_path + 'image_68.jpg')

# %%
plt.imshow(arr)

# %%
from tensorflow.keras.models import load_model

# %%
model_path = "C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL\\E2E_RNN_Sentiment_Analysis\\models\\RNN"
# Load your trained model
model = load_model(model_path )
# Out:
# WARNING:tensorflow:Unused attribute in object (root).layer_with_weights-0._index_lookup_layer._table: ['table', 'table']
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-318a5eaaea13> in <module>
#       1 model_path = "C:\\Users\\fenil\\OneDrive\\Desktop\\E2E DL\\E2E_RNN_Sentiment_Analysis\\models\\RNN"
#       2 # Load your trained model
# ----> 3 model = load_model(model_path )
#
# ...

# %%
from tensorflow.keras.models
